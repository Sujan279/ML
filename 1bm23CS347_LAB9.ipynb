# %% [markdown]
# <a href="https://colab.research.google.com/github/Sujan279/ML/blob/main/1bm23CS347_LAB9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1bf6d821-de90-4182-b0de-51fbeab43fae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1bf6d821-de90-4182-b0de-51fbeab43fae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

df = pd.read_csv("iris (1) (1).csv")

X = df[['petal_length', 'petal_width']]

scaler = StandardScaler()
X = scaler.fit_transform(X)

wcss = []
for k in range(1, 11):
    km = KMeans(n_clusters=k, n_init=10)
    km.fit(X)
    wcss.append(km.inertia_)

plt.plot(range(1, 11), wcss, marker='o')
plt.xlabel('K')
plt.ylabel('WCSS')
plt.show()

kmeans = KMeans(n_clusters=3, n_init=10)
df['cluster'] = kmeans.fit_predict(X)

print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  cluster
# 0           5.1          3.5           1.4          0.2  Iris-setosa        1
# 1           4.9          3.0           1.4          0.2  Iris-setosa        1
# 2           4.7          3.2           1.3          0.2  Iris-setosa        1
# 3           4.6          3.1           1.5          0.2  Iris-setosa        1
# 4           5.0          3.6           1.4          0.2  Iris-setosa        1
